# %% [markdown]
# <a href="https://colab.research.google.com/github/daniel1pontes/Workshop-Dados-25.2/blob/main/desafioEtl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/dados_nao_tratados.csv')
df
# Out:
#    id       nome         idade data_inscricao nota  ativo
# 0   1        Ana            25     2023-05-12  8.5    Sim
# 1   2      Bruno  vinte e três     2023/13/01  9.0   TRUE
# 2   3      Carla            30            NaN  NaN    Não
# 3   4     Daniel           NaN     2022-07-15  7.2    sim
# 4   5      Érica            27     2022-08-XX    8      e
# 5   6  Francisco            29     15/09/2022  dez  FALSE
# 6   7   Gabriela            21     2023-01-05   10   TRUE
# 7   8   Henrique            19     2023-02-30  9.5    nao
# 8   9      Ivana            11     2023-03-10  NaN    Yes
# 9  10       José             ?     2022-11-25  6.7    sim

# %%
df["ativo"] = df["ativo"].str.strip().map({'sim': True,'Não':False, 'Sim': True,'TRUE': True, 'TRUE': True, 'e': None,'FALSE': False,'nao': False,'Yes': True })
df
# Out:
#    id       nome         idade data_inscricao nota  ativo
# 0   1        Ana            25     2023-05-12  8.5   True
# 1   2      Bruno  vinte e três     2023/13/01  9.0   True
# 2   3      Carla            30            NaN  NaN  False
# 3   4     Daniel           NaN     2022-07-15  7.2   True
# 4   5      Érica            27     2022-08-XX    8   None
# 5   6  Francisco            29     15/09/2022  dez  False
# 6   7   Gabriela            21     2023-01-05   10   True
# 7   8   Henrique            19     2023-02-30  9.5  False
# 8   9      Ivana            11     2023-03-10  NaN   True
# 9  10       José             ?     2022-11-25  6.7   True

# %%
df.replace('dez', 10, inplace=True)
df['nota'] = pd.to_numeric(df['nota'], errors='coerce')
df
# Out:
#    id       nome         idade data_inscricao  nota  ativo
# 0   1        Ana            25     2023-05-12   8.5   True
# 1   2      Bruno  vinte e três     2023/13/01   9.0   True
# 2   3      Carla            30            NaN   NaN  False
# 3   4     Daniel           NaN     2022-07-15   7.2   True
# 4   5      Érica            27     2022-08-XX   8.0   None
# 5   6  Francisco            29     15/09/2022  10.0  False
# 6   7   Gabriela            21     2023-01-05  10.0   True
# 7   8   Henrique            19     2023-02-30   9.5  False
# 8   9      Ivana            11     2023-03-10   NaN   True
# 9  10       José             ?     2022-11-25   6.7   True

# %%
df['data_inscricao'] = pd.to_datetime(df['data_inscricao'], errors='coerce')
df
# Out:
#    id       nome         idade data_inscricao  nota  ativo
# 0   1        Ana            25     2023-05-12   8.5   True
# 1   2      Bruno  vinte e três            NaT   9.0   True
# 2   3      Carla            30            NaT   NaN  False
# 3   4     Daniel           NaN     2022-07-15   7.2   True
# 4   5      Érica            27            NaT   8.0   None
# 5   6  Francisco            29            NaT  10.0  False
# 6   7   Gabriela            21     2023-01-05  10.0   True
# 7   8   Henrique            19            NaT   9.5  False
# 8   9      Ivana            11     2023-03-10   NaN   True
# 9  10       José             ?     2022-11-25   6.7   True

# %%
df.replace('vinte e três', 23, inplace=True)
df["idade"] = pd.to_numeric(df["idade"], errors="coerce")
df
# Out:
#    id       nome  idade data_inscricao  nota  ativo
# 0   1        Ana   25.0     2023-05-12   8.5   True
# 1   2      Bruno   23.0            NaT   9.0   True
# 2   3      Carla   30.0            NaT   NaN  False
# 3   4     Daniel    NaN     2022-07-15   7.2   True
# 4   5      Érica   27.0            NaT   8.0   None
# 5   6  Francisco   29.0            NaT  10.0  False
# 6   7   Gabriela   21.0     2023-01-05  10.0   True
# 7   8   Henrique   19.0            NaT   9.5  False
# 8   9      Ivana   11.0     2023-03-10   NaN   True
# 9  10       José    NaN     2022-11-25   6.7   True
